# %% [markdown]
# <span style="font-size:25px; font-weight:bold">Name: Wondwosen Muhea</span><br>
# <span style="font-size:20px; font-weight:bold">Course: Advanced Big Data and Data Mining (MSCS-634-M40) </span><br>
# <span style="font-size:16px; font-weight:bold">Residence Classification and Clustering Delivery 3</span><br>

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import (confusion_matrix, ConfusionMatrixDisplay,
                             roc_auc_score, roc_curve, RocCurveDisplay,
                             accuracy_score, f1_score, classification_report, silhouette_score)
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from mlxtend.frequent_patterns import apriori, association_rules
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import label_binarize
from sklearn.inspection import permutation_importance 
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ### 1. Classification algorithms
# In housing market analytics, not every task is about predicting exact prices.
# Often, we’re more interested in categorizing homes into meaningful segments
# based on their market value — such as High, Mid, or Low price bands.
# This approach helps:
# - Buyers quickly identify homes within their budget.
# - Sellers and agents understand where a property stands relative to others.
# - Analysts and city planners assess trends across different neighborhoods or market conditions.
#
# By converting the continuous SalePrice into discrete classes:
# - We simplify the modeling task,
# - Enable interpretability, and
# - Support strategic decision-making like pricing tiers, marketing plans, or affordability analysis.
# In this project, we classified homes based on price bands using two models — Decision Tree and k-Nearest Neighbors (k-NN) — to evaluate how well we can automatically categorize homes and gain insights from the misclassification patterns.

# %%
# 1. Load Ames Housing (Kaggle “train.csv” file)
df = pd.read_csv("AmesHousing.csv")    # adjust path if needed
print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (2930, 82)
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
# ...

# %%
# 2. Basic cleaning mimicking regression workflow
num_cols = df.select_dtypes(include="number").columns

# Interpolate only the numeric part
df[num_cols] = df[num_cols].interpolate(limit_direction="both")                 
df.drop_duplicates()# safety against dups

# IQR trim on SalePrice
q1,q3 = df['SalePrice'].quantile([0.25,0.75]); iqr=q3-q1
df = df[df['SalePrice'].between(q1-1.5*iqr, q3+1.5*iqr)].reset_index(drop=True)

# Ordinal maps
qual_map = {'Po':1,'Fa':2,'TA':3,'Gd':4,'Ex':5,'None':0}
ord_cols = ['Exter Qual','Exter Cond','Bsmt Qual','Bsmt Cond',
            'Bsmt Exposure','Kitchen Qual','Heating QC','Garage Qual','Garage Cond']

for col in ord_cols:
    df[col] = df[col].fillna('None').map(qual_map).astype(float)

print("After clean:", df.shape)
df[ord_cols].head()
# Out:
# After clean: (2793, 82)
#    Exter Qual  Exter Cond  Bsmt Qual  Bsmt Cond  Bsmt Exposure  Kitchen Qual  \
# 0         3.0         3.0        3.0        4.0            4.0           3.0
# 1         3.0         3.0        3.0        3.0            NaN           3.0
# 2         3.0         3.0        3.0        3.0            NaN           4.0
# 3         4.0         3.0        3.0        3.0            NaN           5.0
# 4         3.0         3.0        4.0        3.0            NaN           3.0
#
#    Heating QC  Garage Qual  Garage Cond
# 0         2.0          3.0          3.0
# 1         3.0          3.0          3.0
# 2         3.0          3.0          3.0
# 3         5.0          3.0          3.0
# 4         4.0          3.0          3.0

# %%
# target tiers
df['PriceTier'] = pd.qcut(df['SalePrice'], q=3, labels=['Low','Mid','High'])
X = df.drop(columns=['SalePrice','PriceTier'])
y = df['PriceTier']

le = LabelEncoder(); y_enc = le.fit_transform(y)

num_cols = X.select_dtypes('number').columns
cat_cols = X.select_dtypes('object').columns

preprocess = ColumnTransformer([
    ('num', Pipeline([
        ('imp', SimpleImputer(strategy='median')),
        ('sc',  StandardScaler())
    ]), num_cols),
    ('cat', Pipeline([
        ('imp', SimpleImputer(strategy='constant', fill_value='Missing')),
        ('ohe', OneHotEncoder(handle_unknown='ignore'))
    ]), cat_cols)
])

X_train,X_test,y_train,y_test = train_test_split(
    X, y_enc, test_size=0.2, stratify=y_enc, random_state=42)

# %% [markdown]
# ### Analysis
# Purpose: prepare raw data for modeling with clean, interpretable, and structured values
#
# #### Infer_objects(copy=False)
# - Converts mixed-type object columns into proper int/float types
# - Why: Ensures numerical operations (like interpolation or modeling) won’t fail due to hidden string values.
# #### Interpolate(limit_direction='both') (on numeric cols)
# - Fills small gaps in numeric features using linear interpolation
# - Why: Keeps the continuous trend in features like Lot Frontage, Garage Yr Blt, etc., rather than dropping rows or using fixed values.
# #### .drop_duplicates()
# - Removes any repeated rows
# - Why: Prevents model from being biased by duplicate examples, which could distort evaluation or training.
# #### Outlier removal using IQR rule on SalePrice
# - Removes points outside 1.5×IQR from Q1/Q3
# - Why: Trims extremely expensive/cheap houses that could skew classification into price tiers and reduce generalization.
# #### Ordinal mapping (ExterQual, BsmtQual, etc.)
# - Replaces text levels (Ex, Gd, etc.) with integers {Po:1 … Ex:5}, or 0 if missing
# - Why: Preserves the true order of quality/condition scores for regression or tree-based models. Treats “Excellent” as better than “Good” rather than just different.

# %% [markdown]
# #### Preprocess & Train/Test Split
# ###### PriceTier via pd.qcut
# - Splits SalePrice into 3 equal-sized classes: Low, Mid, High
# - Why: Transforms regression target into a multi-class problem for classification models. Ensures balanced class representation.
# ###### LabelEncoder on target
# - Converts tier labels to numerical values (0/1/2)
# - Why: Most classifiers (k-NN, Tree, SVM) require numeric target labels.
# ###### Feature grouping: num_cols vs. cat_cols
# - Separates numeric (int/float) from object (string) columns
# - Why: Preprocessing must apply different strategies to each type — scaling for numbers, encoding for categories.
# ###### ColumnTransformer: preprocess
# For num:
# - Imputes missing numeric values with median
# - Why: More robust than mean when outliers are present.
# ###### Scales features to standard normal
# - Why: k-NN and SVM rely on distance; scaling prevents large-range features from dominating.
# cat:
# ###### Fills missing with 'Missing' then one-hot encodes
# - Why: Ensures all categories are represented and models don’t fail when encountering unknowns.
# - Overall Why: Prevents data leakage and maintains compatibility during cross-validation and pipeline execution.
# ###### train_test_split(..., stratify=y_enc)
# - Stratified 80/20 split with fixed random_state
# - Why: Maintains class balance across train/test; makes results reproducible and fair for all models.

# %%
# Decision Tree
tree_pipe = Pipeline([
    ('prep', preprocess),
    ('clf',  DecisionTreeClassifier(min_samples_leaf=5, random_state=42))
]).fit(X_train, y_train)

# k-NN search
knn_pipe = Pipeline([('prep', preprocess), ('clf', KNeighborsClassifier())])
grid = {'clf__n_neighbors':[3,5,7,11],
        'clf__weights':['uniform','distance'],
        'clf__p':[1,2]}
knn_best = GridSearchCV(knn_pipe, grid, cv=5,
                        scoring='accuracy', n_jobs=1   # ← changed
                       ).fit(X_train, y_train).best_estimator_
print("Best k-NN:", knn_best.named_steps['clf'])
# Out:
# Best k-NN: KNeighborsClassifier(n_neighbors=11, weights='distance')

# %%
def eval_model(name, model):
    pred_enc = model.predict(X_test)
    pred_lbl = le.inverse_transform(pred_enc)
    true_lbl = le.inverse_transform(y_test)
    acc = accuracy_score(true_lbl, pred_lbl)
    f1  = f1_score(true_lbl, pred_lbl, average="weighted")
    return acc, f1, true_lbl, pred_lbl

tree_acc, tree_f1, t_true, t_pred = eval_model("Tree", tree_pipe)
knn_acc,  knn_f1,  k_true, k_pred = eval_model("kNN", knn_best)

print(f"{'Model':12s}  Accuracy   F1")
print(f"DecisionTree  {tree_acc:.3f}    {tree_f1:.3f}")
print(f"k-NN          {knn_acc:.3f}    {knn_f1:.3f}")
# Out:
# Model         Accuracy   F1
# DecisionTree  0.757    0.758
# k-NN          0.814    0.813

# %%
# Tree importances
tree_feats = pd.DataFrame({
    "Feature": tree_pipe.named_steps["prep"].get_feature_names_out(),
    "Importance": tree_pipe.named_steps["clf"].feature_importances_
}).sort_values("Importance", ascending=False).head(15)

# k-NN does not supply importances natively; we’ll use same top Tree list
print("Top Decision-Tree features:")
tree_feats.head(10)
# Out:
# Top Decision-Tree features:
#                      Feature  Importance
# 5          num__Overall Qual    0.293878
# 23          num__Gr Liv Area    0.125083
# 18        num__Total Bsmt SF    0.102615
# 34          num__Garage Cars    0.097862
# 238  cat__Garage Type_Detchd    0.043692
# 0                 num__Order    0.028377
# 15         num__BsmtFin SF 1    0.028357
# 1                   num__PID    0.019959
# 8        num__Year Remod/Add    0.019249
# 35          num__Garage Area    0.018970

# %%
def eval(model): 
    pred = model.predict(X_test)
    return accuracy_score(y_test,pred), f1_score(y_test,pred,average='weighted'), pred

dt_acc,dt_f1,dt_pred = eval(tree_pipe)
kn_acc,kn_f1,kn_pred = eval(knn_best)

print(f"{'Model':13s}  Acc   F1")
print(f"Decision Tree  {dt_acc:.3f} {dt_f1:.3f}")
print(f"k-NN           {kn_acc:.3f} {kn_f1:.3f}")

fig,ax = plt.subplots(2,2,figsize=(12,9))
for (pred,title,a0,a1) in [(dt_pred,'DT',ax[0,0],ax[1,0]),
                           (kn_pred,'k-NN',ax[0,1],ax[1,1])]:
    cm = confusion_matrix(y_test,pred)
    sns.heatmap(cm,annot=True,fmt='d',cmap='Blues',
                xticklabels=le.classes_,yticklabels=le.classes_,ax=a0)
    a0.set(title=f"{title} CM",xlabel='Pred',ylabel='Actual')
    y_bin = label_binarize(y_test, classes=np.unique(y_test))
    y_score = (tree_pipe if title=='DT' else knn_best).predict_proba(X_test)
    for i,cls in enumerate(le.classes_):
        fpr,tpr,_ = roc_curve(y_bin[:,i], y_score[:,i])
        RocCurveDisplay(fpr=fpr,tpr=tpr,estimator_name=cls).plot(ax=a1)
    a1.set_title(f"{title} ROC"); a1.grid(alpha=.3)
plt.tight_layout(); plt.show()
# Out:
# Model          Acc   F1
# Decision Tree  0.757 0.758
# k-NN           0.814 0.813

# %% [markdown]
# ### Observations
# Based on the classification performance comparison of Decision Tree and k-NN classifiers, here’s a detailed analysis of how well they performed in predicting house price bands (High, Mid, Low):
# ##### Based on Scores
# - k-NN outperformed Decision Tree in both accuracy and F1 score.
# - F1 score, which balances precision and recall, is especially relevant here due to the multi-class structure.
# ##### Confusion Matrix Analysis
# ###### Decision Tree:
# - High: Predicted well (148/183), but some are misclassified as Mid.
# - Low: 146/186 correctly classified, but ~19% were labeled as Mid.
# - Mid: Struggles most with this class — ~33 samples misclassified as Low, 28 as High.
# - Insight: DT learns strong, sharp rules which can misfire when features overlap, especially for the Mid band.
# ##### k-NN:
# - High: Very strong (159/183), very few false positives.
# - Low: Almost perfect (163/186), only minor confusion with Mid.
# - Mid: Still the hardest class — 39 labeled as Low, 18 as High.
# - Insight: k-NN benefits from neighborhood similarity, handling overlapping data better. It’s more robust for boundary cases, such as between Low and Mid.
# ##### ROC Curve Comparison
# - Both models show excellent AUC performance across all classes.
# - k-NN has tighter, steeper curves, especially for High and Low classes.
# - Decision Tree's Mid curve lags, confirming what we see in the confusion matrix.
#
# ##### Feature Importance of Decision tree
# ##### Top Influential Features
# - Overall Qual (Overall material and finish quality) is by far the most dominant predictor, confirming that subjective quality assessment plays a crucial role in home value.
# - Gr Liv Area, Total Bsmt SF, and Garage Cars — all size-related variables — show strong predictive power. These reflect how usable living space and amenities impact home classification.
# - Garage Type_Detchd being high suggests that type of garage (e.g., detached vs. attached) is a significant categorical factor, likely tied to convenience or style preferences.
# - Variables like Order, PID, or Year Remod/Add have lesser impact but might capture temporal trends or data collection artifacts.

# %% [markdown]
# ### Interpretation of Price Bands
# - High: Easily separable by both models — likely has clear, distinct features (e.g., large size, high quality).
# - Low: Fairly isolated in feature space; both models handle it well.
# - Mid: This band blends characteristics from both sides, causing overlap in feature space and making it consistently harder to classify.
# ### Final Takeaways
# - k-NN is a better fit for this dataset, especially because of the fuzzy boundaries between classes.
# - Decision Tree still provides explainable rules, but over-simplifies the Mid class.
# - Recommendation: Use k-NN for production scoring, but combine with Decision Tree insights for explainability and rule validation.
# - The feature ranking in decision tree confirms that structural quality, living space, and basement size are essential signals in determining a home’s price bracket, insights that align well with buyer expectations and real estate market logic.
# - The feature ranking also justifies the use of Decision Trees for interpretability, helping stakeholders understand which features matter most when classifying homes.

# %%
# Feature importance plot in the decision tree classifier
plt.figure(figsize=(10, 6))
sns.barplot(data=tree_feats.head(15),
            x='Importance', y='Feature',
            hue='Feature', palette='Blues_d', legend=False)
plt.title('Top 15 Feature Importances (Decision Tree)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Final Classification Analysis
# | Metric                    | Decision Tree                                    | k-Nearest Neighbors (k-NN)                         |
# | ------------------------- | ------------------------------------------------ | -------------------------------------------------- |
# | **Accuracy**              | \~0.81                                           | \~0.76                                        |
# | **F1 Score**              | High: \~0.81                                     | Moderate: \~0.76                                   |
# | **Confusion Matrix**      | Clear diagonal dominance, few misclassifications | More spread, especially misclassifying `Mid` class |
# | **ROC Curve (Macro Avg)** | AUC > 0.90 (good separation)                     | AUC \~0.85 (acceptable but less sharp)             |

# %% [markdown]
# ## 2. Clustering algorithms
# ###### Objective:
# - Reduce the 30 original neighborhoods into broader, data-driven “meta-areas” for easier segmentation.
# ###### Pipeline:
# - One-hot encode Neighborhood → 30 binary columns.
# - K-Means (k = 8) and Hierarchical Ward (k = 8) fit on the dummy matrix.
# - PCA-2D projection used only for plotting.
# ###### Cluster naming logic
# - For each algorithm, label = <most-common Neighborhood>-KM or -HIER (e.g., NridgHt-KM).
# - Gives interpretable legends in scatter plots.
# ###### Visual highlights
# - K-Means plot shows compact “blob” clusters (balanced size).
# - Hierarchical plot reveals elongated or nested shapes, capturing finer gradations.

# %%
# 0.  Assemble richer feature matrix
# --------------------------------------------------------
df_mod         = df.copy()
df_mod["LogPrice"] = np.log1p(df_mod["SalePrice"])

num_cols = ["Gr Liv Area","Total Bsmt SF","Garage Cars",
            "Overall Qual","LogPrice"]
cat_cols = ["Neighborhood"]

preproc = ColumnTransformer([
    ("num", StandardScaler(), num_cols),
    ("cat", OneHotEncoder(drop='first', sparse_output=False), cat_cols)
])
X_trans = preproc.fit_transform(df_mod[num_cols+cat_cols])

# --------------------------------------------------------
# 1. Silhouette scan to pick best k
# --------------------------------------------------------
sample_idx = np.random.RandomState(42).choice(len(X_trans), 600, replace=False)
sil_grid = {}
for k in range(3, 11):
    km = KMeans(n_clusters=k, random_state=42, n_init=10).fit(X_trans)
    sil = silhouette_score(X_trans[sample_idx], km.labels_[sample_idx])
    sil_grid[k] = sil
best_k = max(sil_grid, key=sil_grid.get)
print("Silhouette by k:", {k: f"{v:.3f}" for k,v in sil_grid.items()})
print(f"\n▶ Best k = {best_k}  (silhouette {sil_grid[best_k]:.3f})")
# Out:
# Silhouette by k: {3: '0.187', 4: '0.169', 5: '0.175', 6: '0.173', 7: '0.177', 8: '0.172', 9: '0.174', 10: '0.163'}
#
# ▶ Best k = 3  (silhouette 0.187)

# %%
# --------------------------------------------------------
# 2. Fit final K-Means & Ward with best_k
# --------------------------------------------------------
k_pipe = Pipeline([
    ("prep", preproc),
    ("pca",  PCA(n_components=2, random_state=42)),
    ("km",   KMeans(n_clusters=best_k, random_state=42, n_init=10))
]).fit(df_mod[num_cols+cat_cols])

h_pipe = Pipeline([
    ("prep", preproc),
    ("pca",  PCA(n_components=2, random_state=42)),
    ("agg",  AgglomerativeClustering(n_clusters=best_k, linkage='ward'))
]).fit(df_mod[num_cols+cat_cols])

coords_km   = k_pipe.named_steps["pca"].transform(k_pipe.named_steps["prep"].transform(df_mod[num_cols+cat_cols]))
coords_hier = h_pipe.named_steps["pca"].transform(h_pipe.named_steps["prep"].transform(df_mod[num_cols+cat_cols]))
labels_km   = k_pipe.named_steps["km"].labels_
labels_hier = h_pipe.named_steps["agg"].labels_

# %%
# --------------------------------------------------------
# 3. Visual comparison
# --------------------------------------------------------
fig, ax = plt.subplots(1,2, figsize=(11,5))
sns.scatterplot(x=coords_km[:,0], y=coords_km[:,1], hue=labels_km,
                palette='tab10', s=18, ax=ax[0])
ax[0].set_title(f"K-Means (k={best_k})")
ax[0].legend(title='Cluster')

sns.scatterplot(x=coords_hier[:,0], y=coords_hier[:,1], hue=labels_hier,
                palette='tab10', s=18, ax=ax[1])
ax[1].set_title(f"Ward Hierarchical (k={best_k})")
ax[1].legend(title='Cluster')
plt.tight_layout(); plt.show()

# --------------------------------------------------------
# 4. Quick profile table
# --------------------------------------------------------
def profile(df_in, lbl):
    return (df_in.assign(cluster=lbl)
              .groupby('cluster')[["Gr Liv Area","Overall Qual",
                                   "Total Bsmt SF","Garage Cars","SalePrice"]]
              .median().round(0))

display(pd.concat({'K-Means': profile(df_mod, labels_km),
                   'Hier':    profile(df_mod, labels_hier)}, axis=0))
# Out:
#                  Gr Liv Area  Overall Qual  Total Bsmt SF  Garage Cars  \
#         cluster
# K-Means 0             1491.0           6.0          960.0          2.0
#         1             1058.0           5.0          861.0          1.0
#         2             1801.0           8.0         1475.0          2.0
# Hier    0             1092.0           5.0          876.0          1.0
#         1             1572.0           7.0          976.0          2.0
#         2             1880.0           8.0         1518.0          3.0
#
#                  SalePrice
#         cluster
# K-Means 0         170220.0
#         1         120000.0
#         2         252000.0
# Hier    0         127500.0
#         1         185000.0
#         2         270000.0

# %% [markdown]
# ### Key observations
# |                                 | **K-Means (k = 3)**                                                                                                     | **Ward Hierarchical (k = 3)**                                                                                                                                                                   |
# | ------------------------------- | ----------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Visual shape**                | Nearly **symmetrical “sandwich”** – orange on the left, green on the right, blue in the middle.                         | Also three bands, but **blue dominates the centre + left**, pushing orange slightly rightward.                                                                                                  |
# | **Boundary style**              | Hard, straight-line cuts (typical of K-Means’ Voronoi splits).                                                          | Curvier, irregular splits; Ward merges based on distance to cluster centroids and within-cluster variance.                                                                                      |
# | **Outliers / long tails**       | A few far-right green and far-top points remain in the same cluster → K-Means’ centroid pull.                           | Ward sometimes peels those off into blue because hierarchical linkage is sensitive to single-link distances.                                                                                    |
# | **Density balance**             | Clusters look roughly equal in size.                                                                                    | Blue cluster is noticeably larger; Ward merged more borderline points into it.                                                                                                                  |
# | **Interpretation vs. profiles** | • **Blue (Cluster 0)** ≈ Mid-market band.<br>• **Orange (1)** ≈ Budget / compact.<br>• **Green (2)** ≈ Premium / large. | • **Blue (0)** blends some budget with mid-market → broader “Affordable & Mid”.<br>• **Orange (1)** shifts to mid-upper range.<br>• **Green (2)** still the premium tier, but slightly cleaner. |
#
# ##### Both algorithms find three natural strata
# - Budget / Starter (~$120 K, Qual 5, ≤ 1 garage)
# - Mid-market (~$170-185 K, Qual 6–7, 2 garage)
# - Premium (~$250-270 K, Qual 8, largest area, often 3 garage)
# ##### Ward Hierarchical separates the top end more cleanly
# - Adds a 3-car-garage signal in Cluster 2 → strongest “executive” segment.
# - Silhouette advantage of k = 3 is reflected in distinct medians; very little overlap between clusters.
# ### Real-world application
# - Segment	What to do
# ##### Budget / Starter
# • Advertise affordable financing
# • Highlight renovation potential to investors
# ##### Mid-market
# • Appeal to growing families seeking value
# • Competitive pricing + upgrade incentives
# ##### Premium / Executive
# • Feature luxury amenities, 3-car garages
# • Stage homes and use high-end marketing channels
# ### Takeaway
# Three clusters capture the Ames market hierarchy perfectly: budget, mainstream, and premium. Ward’s “Cluster 2” (Premium) is the clearest upscale group, while K-Means merges mid-upper into two clusters. Use these segments for targeted pricing, marketing, and as a powerful categorical feature in downstream models.
